# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle
import xgboost as xgb
sns.set()

#importation des bibliothèques sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from collections import OrderedDict
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split

# from imblearn.over_sampling import SMOTE
from sklearn.metrics import mean_squared_error as MSE
from matplotlib.pyplot import *
import xgboost as XGB
from datetime import datetime
import sqlite3

# %% [raw]
# pip install neptune-contrib[monitoring]

# %%
#importation des données
Dec  = pd.read_csv('Decembre.csv')
Nov = pd.read_csv('Novembre.csv')
Oct = pd.read_csv('maybe.csv')
Sept = pd.read_csv('maybe2.csv')

# %%
Dec = Dec[['tenant', 'ETABLISSEMENT','date', 'GL_TOTALTTC','GL_NUMERO','Sic','CODEISO2','TYPEETAB']]

# %%
Dec.columns = ['Num_Pha', 'Pharmacie','date', 'Total_Prix','NB_boite','Sic','PAYS','TYPEETAB']
Nov.columns = ['Unnamed: 0','Num_Pha', 'Pharmacie','date', 'Total_Prix','NB_boite','Sic','PAYS','TYPEETAB']
Oct.columns = ['Unnamed: 0','Num_Pha', 'Pharmacie','date', 'Total_Prix','NB_boite','Sic','PAYS','TYPEETAB']
Sept.columns = ['Unnamed: 0','Num_cli', 'Pharmacie','date', 'Total_Prix','NB_boite','Sic','PAYS','TYPEETAB']

# %%
Dec
# Out:
#          Num_cli Pharmacie        date  Total_Prix  NB_boite       Sic PAYS  \
# 0       90001909       001  2021-12-01     1830.53        60  90001909   FR
# 1       90001909       001  2021-12-02     1502.24        61  90001909   FR
# 2       90001909       001  2021-12-03     1497.99        60  90001909   FR
# 3       90001909       001  2021-12-04     3975.18       149  90001909   FR
# 4       90001909       001  2021-12-05     1765.42        99  90001909   FR
# ...          ...       ...         ...         ...       ...       ...  ...
# 100382  98684541      7998  2021-12-29     2058.70        19  98684541   FR
# 100383  98684541      7998  2021-12-30     1846.90        21  98684541   FR
# 100384  98684541      7998  2021-12-31     1657.50        15  98684541   FR
# 100385  98684541      8949  2021-12-28      729.34         5  98684541   FR
# 100386  98684541      MKP1  2021-12-28      623.80         5  98684541   FR
#
#        TYPEETAB
# 0           SUC
# 1           SUC
# 2           SUC
# 3           SUC
# 4           SUC
# ...         ...
# 100382      SUC
# 100383      SUC
# 100384      SUC
# 100385      ECO
# 100386      ECO
#
# [100387 rows x 8 columns]

# %%
Nov
# Out:
#        Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0               0  90001909       001  2021-11-01     2699.89       107
# 1               1  90001909       001  2021-11-02     1769.35        69
# 2               2  90001909       001  2021-11-03     1123.15        58
# 3               3  90001909       001  2021-11-04     2104.35        88
# 4               4  90001909       001  2021-11-05     1867.83        86
# ...           ...       ...       ...         ...         ...       ...
# 90148      255125  98684541      7998  2021-11-26     3136.10        28
# 90149      255126  98684541      7998  2021-11-27     2232.60        17
# 90150      255127  98684541      7998  2021-11-29     2495.80        19
# 90151      255128  98684541      7998  2021-11-30      692.00         6
# 90152      255129  98684541      MKP1  2021-11-18      620.00         2
#
#             Sic PAYS TYPEETAB
# 0      90001909   FR      SUC
# 1      90001909   FR      SUC
# 2      90001909   FR      SUC
# 3      90001909   FR      SUC
# 4      90001909   FR      SUC
# ...         ...  ...      ...
# 90148  98684541   FR      SUC
# 90149  98684541   FR      SUC
# 90150  98684541   FR      SUC
# 90151  98684541   FR      SUC
# 90152  98684541   FR      ECO
#
# [90153 rows x 9 columns]

# %%
Nov
# Out:
#        Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0               0  90001909       001  2021-11-01     2699.89       107
# 1               1  90001909       001  2021-11-02     1769.35        69
# 2               2  90001909       001  2021-11-03     1123.15        58
# 3               3  90001909       001  2021-11-04     2104.35        88
# 4               4  90001909       001  2021-11-05     1867.83        86
# ...           ...       ...       ...         ...         ...       ...
# 90148      255125  98684541      7998  2021-11-26     3136.10        28
# 90149      255126  98684541      7998  2021-11-27     2232.60        17
# 90150      255127  98684541      7998  2021-11-29     2495.80        19
# 90151      255128  98684541      7998  2021-11-30      692.00         6
# 90152      255129  98684541      MKP1  2021-11-18      620.00         2
#
#             Sic PAYS TYPEETAB
# 0      90001909   FR      SUC
# 1      90001909   FR      SUC
# 2      90001909   FR      SUC
# 3      90001909   FR      SUC
# 4      90001909   FR      SUC
# ...         ...  ...      ...
# 90148  98684541   FR      SUC
# 90149  98684541   FR      SUC
# 90150  98684541   FR      SUC
# 90151  98684541   FR      SUC
# 90152  98684541   FR      ECO
#
# [90153 rows x 9 columns]

# %%
Oct
# Out:
#        Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0               0  90001909       001  2021-10-06     1456.54        77
# 1               1  90001909       001  2021-10-07     1452.25        69
# 2               2  90001909       001  2021-10-08     1445.66        65
# 3               3  90001909       001  2021-10-09     2081.56       117
# 4               4  90001909       001  2021-10-11     2032.72        95
# ...           ...       ...       ...         ...         ...       ...
# 89360      140339  98684541      7998  2021-10-26     1679.00        13
# 89361      140340  98684541      7998  2021-10-27     1254.30        11
# 89362      140341  98684541      7998  2021-10-28     1205.40         9
# 89363      140342  98684541      7998  2021-10-29     2134.50        22
# 89364      140343  98684541      7998  2021-10-30     2918.90        22
#
#             Sic PAYS TYPEETAB
# 0      90001909   FR      SUC
# 1      90001909   FR      SUC
# 2      90001909   FR      SUC
# 3      90001909   FR      SUC
# 4      90001909   FR      SUC
# ...         ...  ...      ...
# 89360  98684541   FR      SUC
# 89361  98684541   FR      SUC
# 89362  98684541   FR      SUC
# 89363  98684541   FR      SUC
# 89364  98684541   FR      SUC
#
# [89365 rows x 9 columns]

# %%
Sept
# Out:
#         Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0                0  90001909       001  2021-09-01     3511.72       141
# 1                1  90001909       001  2021-09-02     2230.77       110
# 2                2  90001909       001  2021-09-03     2635.27       124
# 3                3  90001909       001  2021-09-04     1776.33        85
# 4                4  90001909       001  2021-09-06      703.39        39
# ...            ...       ...       ...         ...         ...       ...
# 104223      188015  98684541      7998  2021-09-25     2909.90        27
# 104224      188016  98684541      7998  2021-09-27     1137.00         7
# 104225      188017  98684541      7998  2021-09-28      863.00         7
# 104226      188018  98684541      7998  2021-09-29     1172.00         9
# 104227      188019  98684541      7998  2021-09-30     1052.50         8
#
#              Sic PAYS TYPEETAB
# 0       90001909   FR      SUC
# 1       90001909   FR      SUC
# 2       90001909   FR      SUC
# 3       90001909   FR      SUC
# 4       90001909   FR      SUC
# ...          ...  ...      ...
# 104223  98684541   FR      SUC
# 104224  98684541   FR      SUC
# 104225  98684541   FR      SUC
# 104226  98684541   FR      SUC
# 104227  98684541   FR      SUC
#
# [104228 rows x 9 columns]

# %%
df_total = pd.concat([Sept,Oct,Nov], ignore_index=True)

# %%
df_total
# Out:
#         Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0                0  90001909       001  2021-09-01     3511.72       141
# 1                1  90001909       001  2021-09-02     2230.77       110
# 2                2  90001909       001  2021-09-03     2635.27       124
# 3                3  90001909       001  2021-09-04     1776.33        85
# 4                4  90001909       001  2021-09-06      703.39        39
# ...            ...       ...       ...         ...         ...       ...
# 283741      255125  98684541      7998  2021-11-26     3136.10        28
# 283742      255126  98684541      7998  2021-11-27     2232.60        17
# 283743      255127  98684541      7998  2021-11-29     2495.80        19
# 283744      255128  98684541      7998  2021-11-30      692.00         6
# 283745      255129  98684541      MKP1  2021-11-18      620.00         2
#
#              Sic PAYS TYPEETAB
# 0       90001909   FR      SUC
# 1       90001909   FR      SUC
# 2       90001909   FR      SUC
# 3       90001909   FR      SUC
# 4       90001909   FR      SUC
# ...          ...  ...      ...
# 283741  98684541   FR      SUC
# 283742  98684541   FR      SUC
# 283743  98684541   FR      SUC
# 283744  98684541   FR      SUC
# 283745  98684541   FR      ECO
#
# [283746 rows x 9 columns]

# %%
df_total["NB_boite"] = df_total["NB_boite"] * 10

# %%
df_total
# Out:
#         Unnamed: 0   Num_cli Pharmacie        date  Total_Prix  NB_boite  \
# 0                0  90001909       001  2021-09-01     3511.72      1410
# 1                1  90001909       001  2021-09-02     2230.77      1100
# 2                2  90001909       001  2021-09-03     2635.27      1240
# 3                3  90001909       001  2021-09-04     1776.33       850
# 4                4  90001909       001  2021-09-06      703.39       390
# ...            ...       ...       ...         ...         ...       ...
# 283741      255125  98684541      7998  2021-11-26     3136.10       280
# 283742      255126  98684541      7998  2021-11-27     2232.60       170
# 283743      255127  98684541      7998  2021-11-29     2495.80       190
# 283744      255128  98684541      7998  2021-11-30      692.00        60
# 283745      255129  98684541      MKP1  2021-11-18      620.00        20
#
#              Sic PAYS TYPEETAB
# 0       90001909   FR      SUC
# 1       90001909   FR      SUC
# 2       90001909   FR      SUC
# 3       90001909   FR      SUC
# 4       90001909   FR      SUC
# ...          ...  ...      ...
# 283741  98684541   FR      SUC
# 283742  98684541   FR      SUC
# 283743  98684541   FR      SUC
# 283744  98684541   FR      SUC
# 283745  98684541   FR      ECO
#
# [283746 rows x 9 columns]

# %%
df_total.drop(columns = ["Unnamed: 0"], inplace = True)
df_total
# Out:
#          Num_cli Pharmacie        date  Total_Prix  NB_boite       Sic PAYS  \
# 0       90001909       001  2021-09-01     3511.72      1410  90001909   FR
# 1       90001909       001  2021-09-02     2230.77      1100  90001909   FR
# 2       90001909       001  2021-09-03     2635.27      1240  90001909   FR
# 3       90001909       001  2021-09-04     1776.33       850  90001909   FR
# 4       90001909       001  2021-09-06      703.39       390  90001909   FR
# ...          ...       ...         ...         ...       ...       ...  ...
# 283741  98684541      7998  2021-11-26     3136.10       280  98684541   FR
# 283742  98684541      7998  2021-11-27     2232.60       170  98684541   FR
# 283743  98684541      7998  2021-11-29     2495.80       190  98684541   FR
# 283744  98684541      7998  2021-11-30      692.00        60  98684541   FR
# 283745  98684541      MKP1  2021-11-18      620.00        20  98684541   FR
#
#        TYPEETAB
# 0           SUC
# 1           SUC
# 2           SUC
# 3           SUC
# 4           SUC
# ...         ...
# 283741      SUC
# 283742      SUC
# 283743      SUC
# 283744      SUC
# 283745      ECO
#
# [283746 rows x 8 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.options.display.max_columns = 3500
pd.options.display.max_rows = 3500
pd.set_option("max_colwidth", 3500)

# %%
def date_features(df):

    df['date'] = pd.to_datetime(df['date'])
    df['month'] = df.date.dt.month
    df['day'] = df.date.dt.day
    df['dayofyear'] = df.date.dt.dayofyear
    df['dayofweek'] = df.date.dt.dayofweek
    df['is_month_start'] = df.date.dt.is_month_start.astype(int)
    df['is_month_end'] = df.date.dt.is_month_end.astype(int) 
    
    df.drop('date', axis=1, inplace=True)
    
    return df

Dec, df_total =  date_features(Dec), date_features(df_total)

# %%
Dec.loc[(Dec['dayofweek'] == 5) | (Dec['dayofweek'] == 6), 'is_wknd'] = 1
Dec.loc[Dec['is_wknd'].isnull(), 'is_wknd'] = 0

# %%
df_total.loc[(df_total['dayofweek'] == 5) | (df_total['dayofweek'] == 6), 'is_wknd'] = 1
df_total.loc[df_total['is_wknd'].isnull(), 'is_wknd'] = 0

# %%
df_total['daily_avg']  = df_total.groupby(['Num_cli','Pharmacie','dayofweek','is_wknd','is_month_start','is_month_end'])['NB_boite'].transform('mean')
df_total['monthly_avg'] = df_total.groupby(['Num_cli','Pharmacie','month','is_wknd','is_month_start','is_month_end'])['NB_boite'].transform('mean')

# %%
Dec['daily_avg']  = Dec.groupby(['Num_cli','Pharmacie','dayofweek','is_wknd','is_month_start','is_month_end'])['NB_boite'].transform('mean')
Dec['monthly_avg'] = Dec.groupby(['Num_cli','Pharmacie','month','is_wknd','is_month_start','is_month_end'])['NB_boite'].transform('mean')

# %% [markdown]
# # moyenne glissante des ventes par pharmacies des 10 derniers jours
# rolling_10 = df_total.groupby(['tenant','ETABLISSEMENT'])['GL_NUMERO'].rolling(10).mean().reset_index()
# df_total['rolling_mean10'] = rolling_10['GL_NUMERO']
#
# rolling_10 = Dec.groupby(['tenant','ETABLISSEMENT'])['GL_NUMERO'].rolling(10).mean().reset_index()
# Dec['rolling_mean10'] = Dec['GL_NUMERO']

# %%
Dec
# Out:
#          Num_cli Pharmacie  Total_Prix  NB_boite       Sic PAYS TYPEETAB  \
# 0       90001909       001     1830.53        60  90001909   FR      SUC
# 1       90001909       001     1502.24        61  90001909   FR      SUC
# 2       90001909       001     1497.99        60  90001909   FR      SUC
# 3       90001909       001     3975.18       149  90001909   FR      SUC
# 4       90001909       001     1765.42        99  90001909   FR      SUC
# ...          ...       ...         ...       ...       ...  ...      ...
# 100382  98684541      7998     2058.70        19  98684541   FR      SUC
# 100383  98684541      7998     1846.90        21  98684541   FR      SUC
# 100384  98684541      7998     1657.50        15  98684541   FR      SUC
# 100385  98684541      8949      729.34         5  98684541   FR      ECO
# 100386  98684541      MKP1      623.80         5  98684541   FR      ECO
#
#         month  day  dayofyear  dayofweek  is_month_start  is_month_end  \
# 0          12    1        335          2               1             0
# 1          12    2        336          3               0             0
# 2          12    3        337          4               0             0
# 3          12    4        338          5               0             0
# 4          12    5        339          6               0             0
# ...       ...  ...        ...        ...             ...           ...
# 100382     12   29        363          2               0             0
# 100383     12   30        364          3               0             0
# 100384     12   31        365          4               0             1
# 100385     12   28        362          1               0             0
# 100386     12   28        362          1               0             0
#
#         is_wknd  daily_avg  monthly_avg
# 0          0.00      60.00        60.00
# 1          0.00     154.60       157.81
# 2          0.00     152.75       157.81
# 3          1.00     202.67       166.67
# 4          1.00     130.67       166.67
# ...         ...        ...          ...
# 100382     0.00      17.75        15.14
# 100383     0.00      15.60        15.14
# 100384     0.00      15.00        15.00
# 100385     0.00       5.00         5.00
# 100386     0.00       5.00         5.00
#
# [100387 rows x 16 columns]

# %%
df_total
# Out:
#          Num_cli Pharmacie  Total_Prix  NB_boite       Sic PAYS TYPEETAB  \
# 0       90001909       001     3511.72      1410  90001909   FR      SUC
# 1       90001909       001     2230.77      1100  90001909   FR      SUC
# 2       90001909       001     2635.27      1240  90001909   FR      SUC
# 3       90001909       001     1776.33       850  90001909   FR      SUC
# 4       90001909       001      703.39       390  90001909   FR      SUC
# ...          ...       ...         ...       ...       ...  ...      ...
# 283741  98684541      7998     3136.10       280  98684541   FR      SUC
# 283742  98684541      7998     2232.60       170  98684541   FR      SUC
# 283743  98684541      7998     2495.80       190  98684541   FR      SUC
# 283744  98684541      7998      692.00        60  98684541   FR      SUC
# 283745  98684541      MKP1      620.00        20  98684541   FR      ECO
#
#         month  day  dayofyear  dayofweek  is_month_start  is_month_end  \
# 0           9    1        244          2               1             0
# 1           9    2        245          3               0             0
# 2           9    3        246          4               0             0
# 3           9    4        247          5               0             0
# 4           9    6        249          0               0             0
# ...       ...  ...        ...        ...             ...           ...
# 283741     11   26        330          4               0             0
# 283742     11   27        331          5               0             0
# 283743     11   29        333          0               0             0
# 283744     11   30        334          1               0             1
# 283745     11   18        322          3               0             0
#
#         is_wknd  daily_avg  monthly_avg
# 0          0.00    1410.00      1410.00
# 1          0.00     816.36       821.67
# 2          0.00     886.36       821.67
# 3          1.00    1181.82       953.33
# 4          0.00     531.11       821.67
# ...         ...        ...          ...
# 283741     0.00     140.00        99.50
# 283742     1.00     220.77       182.50
# 283743     0.00      81.67        99.50
# 283744     0.00      60.00        60.00
# 283745     0.00      20.00        20.00
#
# [283746 rows x 16 columns]

# %%
correlations = df_total.corr()['NB_boite'].sort_values()
correlations = correlations.reset_index().values
print(df_total.shape)
# Out:
# (283746, 16)

# %%
correlations
# Out:
# array([['dayofyear', -0.03065461360576392],
#        ['month', -0.029843241292646292],
#        ['Num_cli', -0.02480383702152617],
#        ['Sic', -0.02480383702152617],
#        ['day', -0.00839734956576693],
#        ['is_month_end', -0.0058034155857373815],
#        ['is_month_start', 0.008186253199071411],
#        ['Total_Prix', 0.056834352678215676],
#        ['dayofweek', 0.1404818844889405],
#        ['is_wknd', 0.16869983472654831],
#        ['monthly_avg', 0.9435263426092678],
#        ['daily_avg', 0.9509318020908728],
#        ['NB_boite', 1.0]], dtype=object)

# %%
correlations = df_total.corr()['NB_boite'].sort_values()
print('Most Positive Correlations:\n', correlations.tail())
print('\nMost Negative Correlations:\n', correlations.head())
# Out:
# Most Positive Correlations:
#  dayofweek     0.14
# is_wknd       0.17
# monthly_avg   0.94
# daily_avg     0.95
# NB_boite      1.00
# Name: NB_boite, dtype: float64
#
# Most Negative Correlations:
#  dayofyear   -0.03
# month       -0.03
# Num_cli     -0.02
# Sic         -0.02
# day         -0.01
# Name: NB_boite, dtype: float64

# %%
plt.figure(figsize=(10,10)) 
sns.heatmap(df_total.corr(),annot=True,cmap="rainbow_r")

# %%
Dec['id'] = pd.factorize(Dec['Num_cli'])[0]

# %%
Dec = Dec[~Dec.index.duplicated()]

# %%
Dec = Dec.loc[:,~Dec.columns.duplicated()]

# %%
df_total = df_total.loc[:,~df_total.columns.duplicated()]

# %%
df_total
# Out:
#          Num_cli Pharmacie  Total_Prix  NB_boite       Sic PAYS TYPEETAB  \
# 0       90001909       001     3511.72      1410  90001909   FR      SUC
# 1       90001909       001     2230.77      1100  90001909   FR      SUC
# 2       90001909       001     2635.27      1240  90001909   FR      SUC
# 3       90001909       001     1776.33       850  90001909   FR      SUC
# 4       90001909       001      703.39       390  90001909   FR      SUC
# ...          ...       ...         ...       ...       ...  ...      ...
# 283741  98684541      7998     3136.10       280  98684541   FR      SUC
# 283742  98684541      7998     2232.60       170  98684541   FR      SUC
# 283743  98684541      7998     2495.80       190  98684541   FR      SUC
# 283744  98684541      7998      692.00        60  98684541   FR      SUC
# 283745  98684541      MKP1      620.00        20  98684541   FR      ECO
#
#         month  day  dayofyear  dayofweek  is_month_start  is_month_end  \
# 0           9    1        244          2               1             0
# 1           9    2        245          3               0             0
# 2           9    3        246          4               0             0
# 3           9    4        247          5               0             0
# 4           9    6        249          0               0             0
# ...       ...  ...        ...        ...             ...           ...
# 283741     11   26        330          4               0             0
# 283742     11   27        331          5               0             0
# 283743     11   29        333          0               0             0
# 283744     11   30        334          1               0             1
# 283745     11   18        322          3               0             0
#
#         is_wknd  daily_avg  monthly_avg
# 0          0.00    1410.00      1410.00
# 1          0.00     816.36       821.67
# 2          0.00     886.36       821.67
# 3          1.00    1181.82       953.33
# 4          0.00     531.11       821.67
# ...         ...        ...          ...
# 283741     0.00     140.00        99.50
# 283742     1.00     220.77       182.50
# 283743     0.00      81.67        99.50
# 283744     0.00      60.00        60.00
# 283745     0.00      20.00        20.00
#
# [283746 rows x 16 columns]

# %%
conn = sqlite3.connect('Sanofi.db')

# %% [raw]
# engine = create_engine('sqlite:///Sanofi.db')

# %% [raw]
# engine.connect()
# table_names = engine.table_names()
# table_names

# %%
c = conn.cursor()
df_total.to_sql('vente_total', conn, if_exists='append', index= False)

# %%
Dec
# Out:
#          Num_cli Pharmacie  Total_Prix  NB_boite       Sic PAYS TYPEETAB  \
# 0       90001909       001     1830.53        60  90001909   FR      SUC
# 1       90001909       001     1502.24        61  90001909   FR      SUC
# 2       90001909       001     1497.99        60  90001909   FR      SUC
# 3       90001909       001     3975.18       149  90001909   FR      SUC
# 4       90001909       001     1765.42        99  90001909   FR      SUC
# ...          ...       ...         ...       ...       ...  ...      ...
# 100382  98684541      7998     2058.70        19  98684541   FR      SUC
# 100383  98684541      7998     1846.90        21  98684541   FR      SUC
# 100384  98684541      7998     1657.50        15  98684541   FR      SUC
# 100385  98684541      8949      729.34         5  98684541   FR      ECO
# 100386  98684541      MKP1      623.80         5  98684541   FR      ECO
#
#         month  day  dayofyear  dayofweek  is_month_start  is_month_end  \
# 0          12    1        335          2               1             0
# 1          12    2        336          3               0             0
# 2          12    3        337          4               0             0
# 3          12    4        338          5               0             0
# 4          12    5        339          6               0             0
# ...       ...  ...        ...        ...             ...           ...
# 100382     12   29        363          2               0             0
# 100383     12   30        364          3               0             0
# 100384     12   31        365          4               0             1
# 100385     12   28        362          1               0             0
# 100386     12   28        362          1               0             0
#
#         is_wknd  daily_avg  monthly_avg   id
# 0          0.00      60.00        60.00    0
# 1          0.00     154.60       157.81    0
# 2          0.00     152.75       157.81    0
# 3          1.00     202.67       166.67    0
# 4          1.00     130.67       166.67    0
# ...         ...        ...          ...  ...
# 100382     0.00      17.75        15.14  195
# 100383     0.00      15.60        15.14  195
# 100384     0.00      15.00        15.00  195
# 100385     0.00       5.00         5.00  195
# 100386     0.00       5.00         5.00  195
#
# [100387 rows x 17 columns]

# %%
# Nettoyer les données et garder les features fortement corrélés
for df in [df_total, Dec]:
    df.drop([ 
                  #'GL_TOTALTTC',
        'Pharmacie',
                #  'month',
              #    'day',
       # 'is_month_start',
        #'is_month_end',             
        'PAYS',
        'TYPEETAB',
        'Num_cli',
        'Sic',
                  #'dayofyear',
    ],
                 axis=1, 
                 inplace=True)

# %% [raw]
# X_train = df_total.drop('GL_NUMERO', axis=1).dropna()
# y_train = df_total['GL_NUMERO']
# # Test Data
# Dec.sort_values(by=['id'], inplace=True)
# X_test = Dec.drop('id', axis=1)

# %%
df_total.to_csv('df_total.csv')

# %%
model = xgb.XGBRegressor(objective ='reg:squarederror',
                  n_estimators = 10, seed = 123)

# %%
every_column_except_y= [col for col in df_total.columns if col not in ['NB_boite']]
model.fit(df_total[every_column_except_y],df_total['NB_boite'])
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=0, num_parallel_tree=1, random_state=123,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, seed=123,
#              subsample=1, tree_method='exact', validate_parameters=1,
#              verbosity=None)

# %%
feature_important = model.get_booster().get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10))

# %%
Dec.drop(columns=["id"],inplace=True)

# %%
#Y_train = df_total['GL_NUMERO']
#X_train = df_total.drop('GL_NUMERO', axis=1)
X_test = Dec.drop('NB_boite', axis=1)

# %%
test_preds = model.predict(X_test)

# %%
test_preds
# Out:
# array([ 78.46393 , 143.93594 , 150.03323 , ...,  26.838093,  26.251364,
#         20.493618], dtype=float32)

# %%
Dec['pred'] = test_preds

# %%
Dec
# Out:
#         Total_Prix  NB_boite  month  day  dayofyear  dayofweek  \
# 0          1830.53        60     12    1        335          2
# 1          1502.24        61     12    2        336          3
# 2          1497.99        60     12    3        337          4
# 3          3975.18       149     12    4        338          5
# 4          1765.42        99     12    5        339          6
# ...            ...       ...    ...  ...        ...        ...
# 100382     2058.70        19     12   29        363          2
# 100383     1846.90        21     12   30        364          3
# 100384     1657.50        15     12   31        365          4
# 100385      729.34         5     12   28        362          1
# 100386      623.80         5     12   28        362          1
#
#         is_month_start  is_month_end  is_wknd  daily_avg  monthly_avg   pred
# 0                    1             0     0.00      60.00        60.00  78.46
# 1                    0             0     0.00     154.60       157.81 143.94
# 2                    0             0     0.00     152.75       157.81 150.03
# 3                    0             0     1.00     202.67       166.67 271.38
# 4                    0             0     1.00     130.67       166.67 154.55
# ...                ...           ...      ...        ...          ...    ...
# 100382               0             0     0.00      17.75        15.14  34.80
# 100383               0             0     0.00      15.60        15.14  26.84
# 100384               0             1     0.00      15.00        15.00  26.84
# 100385               0             0     0.00       5.00         5.00  26.25
# 100386               0             0     0.00       5.00         5.00  20.49
#
# [100387 rows x 12 columns]

# %%
r = r2_score(Dec['pred'], Dec['NB_boite'])

# %%
r
# Out:
# 0.7229088074106382

# %%
df_total
# Out:
#         Total_Prix  NB_boite  month  day  dayofyear  dayofweek  \
# 0          3511.72      1410      9    1        244          2
# 1          2230.77      1100      9    2        245          3
# 2          2635.27      1240      9    3        246          4
# 3          1776.33       850      9    4        247          5
# 4           703.39       390      9    6        249          0
# ...            ...       ...    ...  ...        ...        ...
# 283741     3136.10       280     11   26        330          4
# 283742     2232.60       170     11   27        331          5
# 283743     2495.80       190     11   29        333          0
# 283744      692.00        60     11   30        334          1
# 283745      620.00        20     11   18        322          3
#
#         is_month_start  is_month_end  is_wknd  daily_avg  monthly_avg
# 0                    1             0     0.00    1410.00      1410.00
# 1                    0             0     0.00     816.36       821.67
# 2                    0             0     0.00     886.36       821.67
# 3                    0             0     1.00    1181.82       953.33
# 4                    0             0     0.00     531.11       821.67
# ...                ...           ...      ...        ...          ...
# 283741               0             0     0.00     140.00        99.50
# 283742               0             0     1.00     220.77       182.50
# 283743               0             0     0.00      81.67        99.50
# 283744               0             1     0.00      60.00        60.00
# 283745               0             0     0.00      20.00        20.00
#
# [283746 rows x 11 columns]

# %%
df_total
# Out:
#         Total_Prix  NB_boite  month  day  dayofyear  dayofweek  \
# 0          3511.72      1410      9    1        244          2
# 1          2230.77      1100      9    2        245          3
# 2          2635.27      1240      9    3        246          4
# 3          1776.33       850      9    4        247          5
# 4           703.39       390      9    6        249          0
# ...            ...       ...    ...  ...        ...        ...
# 283741     3136.10       280     11   26        330          4
# 283742     2232.60       170     11   27        331          5
# 283743     2495.80       190     11   29        333          0
# 283744      692.00        60     11   30        334          1
# 283745      620.00        20     11   18        322          3
#
#         is_month_start  is_month_end  is_wknd  daily_avg  monthly_avg
# 0                    1             0     0.00    1410.00      1410.00
# 1                    0             0     0.00     816.36       821.67
# 2                    0             0     0.00     886.36       821.67
# 3                    0             0     1.00    1181.82       953.33
# 4                    0             0     0.00     531.11       821.67
# ...                ...           ...      ...        ...          ...
# 283741               0             0     0.00     140.00        99.50
# 283742               0             0     1.00     220.77       182.50
# 283743               0             0     0.00      81.67        99.50
# 283744               0             1     0.00      60.00        60.00
# 283745               0             0     0.00      20.00        20.00
#
# [283746 rows x 11 columns]

# %%
Dec.to_csv('Prediction_Decembre.csv')
