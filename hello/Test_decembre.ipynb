# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import pickle
import xgboost as xgb
sns.set()


#importation des bibliothèques sklearn
from sklearn.model_selection import train_test_split
from sklearn.metrics import *
from xgboost import XGBClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn import preprocessing
from collections import OrderedDict
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV, train_test_split

# from imblearn.over_sampling import SMOTE
from sklearn.metrics import mean_squared_error as MSE
from matplotlib.pyplot import *
import xgboost as XGB
from datetime import datetime
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-3249af9ecdf0> in <module>
#       1 import pandas as pd
# ----> 2 import matplotlib.pyplot as plt
#       3 import numpy as np
#       4 import seaborn as sns
#       5 import pickle
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
#importation des données
Dec  = pd.read_csv('Decembre.csv')
Nov = pd.read_csv('Novembre.csv')
Oct = pd.read_csv('maybe.csv')
Sept = pd.read_csv('maybe2.csv')

# %%
Dec = Dec[['tenant', 'ETABLISSEMENT','date', 'GL_TOTALTTC','GL_NUMERO','Sic','CODEISO2','TYPEETAB']]

# %%
Dec
# Out:
#           tenant ETABLISSEMENT        date  GL_TOTALTTC  GL_NUMERO       Sic  \
# 0       90001909           001  2021-12-01  1830.526330         60  90001909
# 1       90001909           001  2021-12-02  1502.242821         61  90001909
# 2       90001909           001  2021-12-03  1497.989600         60  90001909
# 3       90001909           001  2021-12-04  3975.179000        149  90001909
# 4       90001909           001  2021-12-05  1765.424000         99  90001909
# ...          ...           ...         ...          ...        ...       ...
# 100382  98684541          7998  2021-12-29  2058.700000         19  98684541
# 100383  98684541          7998  2021-12-30  1846.900000         21  98684541
# 100384  98684541          7998  2021-12-31  1657.500000         15  98684541
# 100385  98684541          8949  2021-12-28   729.340000          5  98684541
# 100386  98684541          MKP1  2021-12-28   623.800000          5  98684541
#
#        CODEISO2 TYPEETAB
# 0            FR      SUC
# 1            FR      SUC
# 2            FR      SUC
# 3            FR      SUC
# 4            FR      SUC
# ...         ...      ...
# 100382       FR      SUC
# 100383       FR      SUC
# 100384       FR      SUC
# 100385       FR      ECO
# 100386       FR      ECO
#
# [100387 rows x 8 columns]

# %%
Nov
# Out:
#        Unnamed: 0    tenant ETABLISSEMENT        date  GL_TOTALTTC  GL_NUMERO  \
# 0               0  90001909           001  2021-11-01  2699.885987        107
# 1               1  90001909           001  2021-11-02  1769.352004         69
# 2               2  90001909           001  2021-11-03  1123.146000         58
# 3               3  90001909           001  2021-11-04  2104.352600         88
# 4               4  90001909           001  2021-11-05  1867.834400         86
# ...           ...       ...           ...         ...          ...        ...
# 90148      255125  98684541          7998  2021-11-26  3136.100000         28
# 90149      255126  98684541          7998  2021-11-27  2232.600000         17
# 90150      255127  98684541          7998  2021-11-29  2495.800000         19
# 90151      255128  98684541          7998  2021-11-30   692.000000          6
# 90152      255129  98684541          MKP1  2021-11-18   620.000000          2
#
#             Sic CODEISO2 TYPEETAB
# 0      90001909       FR      SUC
# 1      90001909       FR      SUC
# 2      90001909       FR      SUC
# 3      90001909       FR      SUC
# 4      90001909       FR      SUC
# ...         ...      ...      ...
# 90148  98684541       FR      SUC
# 90149  98684541       FR      SUC
# 90150  98684541       FR      SUC
# 90151  98684541       FR      SUC
# 90152  98684541       FR      ECO
#
# [90153 rows x 9 columns]

# %%
Oct
# Out:
#        Unnamed: 0    tenant ETABLISSEMENT        date  GL_TOTALTTC  GL_NUMERO  \
# 0               0  90001909           001  2021-10-06  1456.542004         77
# 1               1  90001909           001  2021-10-07  1452.254000         69
# 2               2  90001909           001  2021-10-08  1445.655200         65
# 3               3  90001909           001  2021-10-09  2081.562400        117
# 4               4  90001909           001  2021-10-11  2032.720000         95
# ...           ...       ...           ...         ...          ...        ...
# 89360      140339  98684541          7998  2021-10-26  1679.000000         13
# 89361      140340  98684541          7998  2021-10-27  1254.300000         11
# 89362      140341  98684541          7998  2021-10-28  1205.400000          9
# 89363      140342  98684541          7998  2021-10-29  2134.500000         22
# 89364      140343  98684541          7998  2021-10-30  2918.900000         22
#
#             Sic CODEISO2 TYPEETAB
# 0      90001909       FR      SUC
# 1      90001909       FR      SUC
# 2      90001909       FR      SUC
# 3      90001909       FR      SUC
# 4      90001909       FR      SUC
# ...         ...      ...      ...
# 89360  98684541       FR      SUC
# 89361  98684541       FR      SUC
# 89362  98684541       FR      SUC
# 89363  98684541       FR      SUC
# 89364  98684541       FR      SUC
#
# [89365 rows x 9 columns]

# %%
Sept
# Out:
#         Unnamed: 0    tenant ETABLISSEMENT        date  GL_TOTALTTC  \
# 0                0  90001909           001  2021-09-01    3511.7220
# 1                1  90001909           001  2021-09-02    2230.7736
# 2                2  90001909           001  2021-09-03    2635.2680
# 3                3  90001909           001  2021-09-04    1776.3340
# 4                4  90001909           001  2021-09-06     703.3888
# ...            ...       ...           ...         ...          ...
# 104223      188015  98684541          7998  2021-09-25    2909.9000
# 104224      188016  98684541          7998  2021-09-27    1137.0000
# 104225      188017  98684541          7998  2021-09-28     863.0000
# 104226      188018  98684541          7998  2021-09-29    1172.0000
# 104227      188019  98684541          7998  2021-09-30    1052.5000
#
#         GL_NUMERO       Sic CODEISO2 TYPEETAB
# 0             141  90001909       FR      SUC
# 1             110  90001909       FR      SUC
# 2             124  90001909       FR      SUC
# 3              85  90001909       FR      SUC
# 4              39  90001909       FR      SUC
# ...           ...       ...      ...      ...
# 104223         27  98684541       FR      SUC
# 104224          7  98684541       FR      SUC
# 104225          7  98684541       FR      SUC
# 104226          9  98684541       FR      SUC
# 104227          8  98684541       FR      SUC
#
# [104228 rows x 9 columns]

# %%
df_total = pd.concat([Sept,Oct,Nov], ignore_index=True)

# %%
df_total
# Out:
#         Unnamed: 0    tenant ETABLISSEMENT        date  GL_TOTALTTC  \
# 0                0  90001909           001  2021-09-01    3511.7220
# 1                1  90001909           001  2021-09-02    2230.7736
# 2                2  90001909           001  2021-09-03    2635.2680
# 3                3  90001909           001  2021-09-04    1776.3340
# 4                4  90001909           001  2021-09-06     703.3888
# ...            ...       ...           ...         ...          ...
# 283741      255125  98684541          7998  2021-11-26    3136.1000
# 283742      255126  98684541          7998  2021-11-27    2232.6000
# 283743      255127  98684541          7998  2021-11-29    2495.8000
# 283744      255128  98684541          7998  2021-11-30     692.0000
# 283745      255129  98684541          MKP1  2021-11-18     620.0000
#
#         GL_NUMERO       Sic CODEISO2 TYPEETAB
# 0             141  90001909       FR      SUC
# 1             110  90001909       FR      SUC
# 2             124  90001909       FR      SUC
# 3              85  90001909       FR      SUC
# 4              39  90001909       FR      SUC
# ...           ...       ...      ...      ...
# 283741         28  98684541       FR      SUC
# 283742         17  98684541       FR      SUC
# 283743         19  98684541       FR      SUC
# 283744          6  98684541       FR      SUC
# 283745          2  98684541       FR      ECO
#
# [283746 rows x 9 columns]

# %%
df_total.drop(columns = ["Unnamed: 0"], inplace = True)
df_total
# Out:
#           tenant ETABLISSEMENT        date  GL_TOTALTTC  GL_NUMERO       Sic  \
# 0       90001909           001  2021-09-01    3511.7220        141  90001909
# 1       90001909           001  2021-09-02    2230.7736        110  90001909
# 2       90001909           001  2021-09-03    2635.2680        124  90001909
# 3       90001909           001  2021-09-04    1776.3340         85  90001909
# 4       90001909           001  2021-09-06     703.3888         39  90001909
# ...          ...           ...         ...          ...        ...       ...
# 283741  98684541          7998  2021-11-26    3136.1000         28  98684541
# 283742  98684541          7998  2021-11-27    2232.6000         17  98684541
# 283743  98684541          7998  2021-11-29    2495.8000         19  98684541
# 283744  98684541          7998  2021-11-30     692.0000          6  98684541
# 283745  98684541          MKP1  2021-11-18     620.0000          2  98684541
#
#        CODEISO2 TYPEETAB
# 0            FR      SUC
# 1            FR      SUC
# 2            FR      SUC
# 3            FR      SUC
# 4            FR      SUC
# ...         ...      ...
# 283741       FR      SUC
# 283742       FR      SUC
# 283743       FR      SUC
# 283744       FR      SUC
# 283745       FR      ECO
#
# [283746 rows x 8 columns]

# %%
pd.set_option('display.float_format', lambda x: '%.2f' % x)
pd.options.display.max_columns = 3500
pd.options.display.max_rows = 3500
pd.set_option("max_colwidth", 3500)

# %%
def date_features(df):

    df['date'] = pd.to_datetime(df['date'])
    df['month'] = df.date.dt.month
    df['day'] = df.date.dt.day
    df['dayofyear'] = df.date.dt.dayofyear
    df['dayofweek'] = df.date.dt.dayofweek
    df['is_month_start'] = df.date.dt.is_month_start.astype(int)
    df['is_month_end'] = df.date.dt.is_month_end.astype(int) 
    
    df.drop('date', axis=1, inplace=True)
    
    return df

Dec, df_total =  date_features(Dec), date_features(df_total)

# %%
Dec.loc[(Dec['dayofweek'] == 5) | (Dec['dayofweek'] == 6), 'is_wknd'] = 1
Dec.loc[Dec['is_wknd'].isnull(), 'is_wknd'] = 0

# %%
df_total.loc[(df_total['dayofweek'] == 5) | (df_total['dayofweek'] == 6), 'is_wknd'] = 1
df_total.loc[df_total['is_wknd'].isnull(), 'is_wknd'] = 0

# %%
df_total['daily_avg']  = df_total.groupby(['tenant','ETABLISSEMENT','dayofweek','is_wknd','is_month_start','is_month_end'])['GL_NUMERO'].transform('mean')
df_total['monthly_avg'] = df_total.groupby(['tenant','ETABLISSEMENT','month','is_wknd','is_month_start','is_month_end'])['GL_NUMERO'].transform('mean')

# %%
Dec['daily_avg']  = Dec.groupby(['tenant','ETABLISSEMENT','dayofweek','is_wknd','is_month_start','is_month_end'])['GL_NUMERO'].transform('mean')
Dec['monthly_avg'] = Dec.groupby(['tenant','ETABLISSEMENT','month','is_wknd','is_month_start','is_month_end'])['GL_NUMERO'].transform('mean')

# %%
# moyenne glissante des ventes par boutique des 10 derniers jours
rolling_10 = df_total.groupby(['tenant','ETABLISSEMENT'])['GL_NUMERO'].rolling(10).mean().reset_index()
df_total['rolling_mean10'] = rolling_10['GL_NUMERO'] 

rolling_10 = Dec.groupby(['tenant'])['GL_NUMERO'].rolling(10).mean().reset_index().drop('level_1', axis=1)
Dec['rolling_mean10'] = rolling_10['GL_NUMERO']

# %%
Dec
# Out:
#           tenant ETABLISSEMENT  GL_TOTALTTC  GL_NUMERO       Sic CODEISO2  \
# 0       90001909           001      1830.53         60  90001909       FR
# 1       90001909           001      1502.24         61  90001909       FR
# 2       90001909           001      1497.99         60  90001909       FR
# 3       90001909           001      3975.18        149  90001909       FR
# 4       90001909           001      1765.42         99  90001909       FR
# ...          ...           ...          ...        ...       ...      ...
# 100382  98684541          7998      2058.70         19  98684541       FR
# 100383  98684541          7998      1846.90         21  98684541       FR
# 100384  98684541          7998      1657.50         15  98684541       FR
# 100385  98684541          8949       729.34          5  98684541       FR
# 100386  98684541          MKP1       623.80          5  98684541       FR
#
#        TYPEETAB  month  day  dayofyear  dayofweek  is_month_start  \
# 0           SUC     12    1        335          2               1
# 1           SUC     12    2        336          3               0
# 2           SUC     12    3        337          4               0
# 3           SUC     12    4        338          5               0
# 4           SUC     12    5        339          6               0
# ...         ...    ...  ...        ...        ...             ...
# 100382      SUC     12   29        363          2               0
# 100383      SUC     12   30        364          3               0
# 100384      SUC     12   31        365          4               0
# 100385      ECO     12   28        362          1               0
# 100386      ECO     12   28        362          1               0
#
#         is_month_end  is_wknd  daily_avg  monthly_avg  rolling_mean10
# 0                  0     0.00      60.00        60.00             NaN
# 1                  0     0.00     154.60       157.81             NaN
# 2                  0     0.00     152.75       157.81             NaN
# 3                  0     1.00     202.67       166.67             NaN
# 4                  0     1.00     130.67       166.67             NaN
# ...              ...      ...        ...          ...             ...
# 100382             0     0.00      17.75        15.14           20.50
# 100383             0     0.00      15.60        15.14           20.90
# 100384             1     0.00      15.00        15.00           20.70
# 100385             0     0.00       5.00         5.00           18.50
# 100386             0     0.00       5.00         5.00           17.00
#
# [100387 rows x 17 columns]

# %%
df_total
# Out:
#           tenant ETABLISSEMENT  GL_TOTALTTC  GL_NUMERO       Sic CODEISO2  \
# 0       90001909           001      3511.72        141  90001909       FR
# 1       90001909           001      2230.77        110  90001909       FR
# 2       90001909           001      2635.27        124  90001909       FR
# 3       90001909           001      1776.33         85  90001909       FR
# 4       90001909           001       703.39         39  90001909       FR
# ...          ...           ...          ...        ...       ...      ...
# 283741  98684541          7998      3136.10         28  98684541       FR
# 283742  98684541          7998      2232.60         17  98684541       FR
# 283743  98684541          7998      2495.80         19  98684541       FR
# 283744  98684541          7998       692.00          6  98684541       FR
# 283745  98684541          MKP1       620.00          2  98684541       FR
#
#        TYPEETAB  month  day  dayofyear  dayofweek  is_month_start  \
# 0           SUC      9    1        244          2               1
# 1           SUC      9    2        245          3               0
# 2           SUC      9    3        246          4               0
# 3           SUC      9    4        247          5               0
# 4           SUC      9    6        249          0               0
# ...         ...    ...  ...        ...        ...             ...
# 283741      SUC     11   26        330          4               0
# 283742      SUC     11   27        331          5               0
# 283743      SUC     11   29        333          0               0
# 283744      SUC     11   30        334          1               0
# 283745      ECO     11   18        322          3               0
#
#         is_month_end  is_wknd  daily_avg  monthly_avg  rolling_mean10
# 0                  0     0.00     141.00       141.00             NaN
# 1                  0     0.00      81.64        82.17             NaN
# 2                  0     0.00      88.64        82.17             NaN
# 3                  0     1.00     118.18        95.33             NaN
# 4                  0     0.00      53.11        82.17             NaN
# ...              ...      ...        ...          ...             ...
# 283741             0     0.00      14.00         9.95           11.60
# 283742             0     1.00      22.08        18.25           12.70
# 283743             0     0.00       8.17         9.95           14.50
# 283744             1     0.00       6.00         6.00           14.40
# 283745             0     0.00       2.00         2.00             NaN
#
# [283746 rows x 17 columns]

# %%
correlations = df_total.corr()['GL_NUMERO'].sort_values()
correlations = correlations.reset_index().values
print(df_total.shape)
# Out:
# (283746, 17)

# %%
correlations
# Out:
# array([['dayofyear', -0.03065461360577941],
#        ['month', -0.029843241292596672],
#        ['tenant', -0.024803837021540924],
#        ['Sic', -0.024803837021540924],
#        ['day', -0.00839734956577147],
#        ['is_month_end', -0.005803415585756738],
#        ['is_month_start', 0.008186253199053169],
#        ['GL_TOTALTTC', 0.05683435267824714],
#        ['rolling_mean10', 0.05936929592501913],
#        ['dayofweek', 0.14048188448907192],
#        ['is_wknd', 0.16869983472632258],
#        ['monthly_avg', 0.943526342609802],
#        ['daily_avg', 0.9509318020912947],
#        ['GL_NUMERO', 1.0]], dtype=object)

# %%
correlations = df_total.corr()['GL_NUMERO'].sort_values()
print('Most Positive Correlations:\n', correlations.tail())
print('\nMost Negative Correlations:\n', correlations.head())
# Out:
# Most Positive Correlations:
#  dayofweek     0.14
# is_wknd       0.17
# monthly_avg   0.94
# daily_avg     0.95
# GL_NUMERO     1.00
# Name: GL_NUMERO, dtype: float64
#
# Most Negative Correlations:
#  dayofyear   -0.03
# month       -0.03
# tenant      -0.02
# Sic         -0.02
# day         -0.01
# Name: GL_NUMERO, dtype: float64

# %%
plt.figure(figsize=(10,10)) 
sns.heatmap(df_total.corr(),annot=True,cmap="rainbow_r")

# %%
Dec['id'] = pd.factorize(Dec['tenant'])[0]

# %%
Dec = Dec[~Dec.index.duplicated()]

# %%
Dec = Dec.loc[:,~Dec.columns.duplicated()]

# %%
df_total = df_total.loc[:,~df_total.columns.duplicated()]

# %%
Dec
# Out:
#           tenant ETABLISSEMENT  GL_TOTALTTC  GL_NUMERO       Sic CODEISO2  \
# 0       90001909           001      1830.53         60  90001909       FR
# 1       90001909           001      1502.24         61  90001909       FR
# 2       90001909           001      1497.99         60  90001909       FR
# 3       90001909           001      3975.18        149  90001909       FR
# 4       90001909           001      1765.42         99  90001909       FR
# ...          ...           ...          ...        ...       ...      ...
# 100382  98684541          7998      2058.70         19  98684541       FR
# 100383  98684541          7998      1846.90         21  98684541       FR
# 100384  98684541          7998      1657.50         15  98684541       FR
# 100385  98684541          8949       729.34          5  98684541       FR
# 100386  98684541          MKP1       623.80          5  98684541       FR
#
#        TYPEETAB  month  day  dayofyear  dayofweek  is_month_start  \
# 0           SUC     12    1        335          2               1
# 1           SUC     12    2        336          3               0
# 2           SUC     12    3        337          4               0
# 3           SUC     12    4        338          5               0
# 4           SUC     12    5        339          6               0
# ...         ...    ...  ...        ...        ...             ...
# 100382      SUC     12   29        363          2               0
# 100383      SUC     12   30        364          3               0
# 100384      SUC     12   31        365          4               0
# 100385      ECO     12   28        362          1               0
# 100386      ECO     12   28        362          1               0
#
#         is_month_end  is_wknd  daily_avg  monthly_avg  rolling_mean10   id
# 0                  0     0.00      60.00        60.00             NaN    0
# 1                  0     0.00     154.60       157.81             NaN    0
# 2                  0     0.00     152.75       157.81             NaN    0
# 3                  0     1.00     202.67       166.67             NaN    0
# 4                  0     1.00     130.67       166.67             NaN    0
# ...              ...      ...        ...          ...             ...  ...
# 100382             0     0.00      17.75        15.14           20.50  195
# 100383             0     0.00      15.60        15.14           20.90  195
# 100384             1     0.00      15.00        15.00           20.70  195
# 100385             0     0.00       5.00         5.00           18.50  195
# 100386             0     0.00       5.00         5.00           17.00  195
#
# [100387 rows x 18 columns]

# %%
# Nettoyer les données et garder les features fortement corrélés
for df in [df_total, Dec]:
    df.drop([ 
                  #'GL_TOTALTTC',
        'ETABLISSEMENT',
                #  'month',
              #    'day',
       # 'is_month_start',
        #'is_month_end',             
        'CODEISO2',
        'TYPEETAB',
        'tenant',
        'Sic',
                  #'dayofyear',
    ],
                 axis=1, 
                 inplace=True)

# %% [raw]
# X_train = df_total.drop('GL_NUMERO', axis=1).dropna()
# y_train = df_total['GL_NUMERO']
# # Test Data
# Dec.sort_values(by=['id'], inplace=True)
# X_test = Dec.drop('id', axis=1)

# %%
df_total.to_csv('df_total.csv')

# %%
model = xgb.XGBRegressor(objective ='reg:linear',
                  n_estimators = 10, seed = 123)

# %% [raw]
# model = xgb.XGBRegressor(colsample_bytree=0.4,
#                  gamma=0,
#                  learning_rate=0.07,
#                  max_depth=3,
#                  min_child_weight=1.5,
#                  n_estimators=10000,
#                  reg_alpha=0.75,
#                  reg_lambda=0.45,
#                  subsample=0.6,
#                  seed=42)

# %%
every_column_except_y= [col for col in df_total.columns if col not in ['GL_NUMERO']]
model.fit(df_total[every_column_except_y],df_total['GL_NUMERO'])
# Out:
# [10:14:29] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# [10:14:30] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.1.0/src/objective/regression_obj.cu:170: reg:linear is now deprecated in favor of reg:squarederror.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=10, n_jobs=0, num_parallel_tree=1,
#              objective='reg:linear', random_state=123, reg_alpha=0,
#              reg_lambda=1, scale_pos_weight=1, seed=123, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
feature_important = model.get_booster().get_score(importance_type='weight')
keys = list(feature_important.keys())
values = list(feature_important.values())

data = pd.DataFrame(data=values, index=keys, columns=["score"]).sort_values(by = "score", ascending=False)
data.nlargest(40, columns="score").plot(kind='barh', figsize = (20,10))

# %%
Dec.drop(columns=["id"],inplace=True)

# %%
#Y_train = df_total['GL_NUMERO']
#X_train = df_total.drop('GL_NUMERO', axis=1)
X_test = Dec.drop('GL_NUMERO', axis=1)

# %%
test_preds = model.predict(X_test)

# %%
test_preds
# Out:
# array([ 71.23358  , 102.642685 ,  99.81131  , ...,  16.113392 ,
#          4.7172403,   4.7172403], dtype=float32)

# %%
Dec['pred'] = test_preds

# %%
Dec
# Out:
#         GL_TOTALTTC  GL_NUMERO  month  day  dayofyear  dayofweek  \
# 0           1830.53         60     12    1        335          2
# 1           1502.24         61     12    2        336          3
# 2           1497.99         60     12    3        337          4
# 3           3975.18        149     12    4        338          5
# 4           1765.42         99     12    5        339          6
# ...             ...        ...    ...  ...        ...        ...
# 100382      2058.70         19     12   29        363          2
# 100383      1846.90         21     12   30        364          3
# 100384      1657.50         15     12   31        365          4
# 100385       729.34          5     12   28        362          1
# 100386       623.80          5     12   28        362          1
#
#         is_month_start  is_month_end  is_wknd  daily_avg  monthly_avg  \
# 0                    1             0     0.00      60.00        60.00
# 1                    0             0     0.00     154.60       157.81
# 2                    0             0     0.00     152.75       157.81
# 3                    0             0     1.00     202.67       166.67
# 4                    0             0     1.00     130.67       166.67
# ...                ...           ...      ...        ...          ...
# 100382               0             0     0.00      17.75        15.14
# 100383               0             0     0.00      15.60        15.14
# 100384               0             1     0.00      15.00        15.00
# 100385               0             0     0.00       5.00         5.00
# 100386               0             0     0.00       5.00         5.00
#
#         rolling_mean10   pred
# 0                  NaN  71.23
# 1                  NaN 102.64
# 2                  NaN  99.81
# 3                  NaN 201.81
# 4                  NaN 133.12
# ...                ...    ...
# 100382           20.50  17.97
# 100383           20.90  17.06
# 100384           20.70  16.11
# 100385           18.50   4.72
# 100386           17.00   4.72
#
# [100387 rows x 13 columns]

# %%
Dec = Dec.reindex(columns=['GL_TOTALTTC','month','day','dayofyear','dayofweek','is_month_start','is_month_end','is_wknd','daily_avg','montly_avg','rolling_mean10','GL_NUMERO','pred'])

# %%
Dec
# Out:
#         GL_TOTALTTC  month  day  dayofyear  dayofweek  is_month_start  \
# 0           1830.53     12    1        335          2               1
# 1           1502.24     12    2        336          3               0
# 2           1497.99     12    3        337          4               0
# 3           3975.18     12    4        338          5               0
# 4           1765.42     12    5        339          6               0
# ...             ...    ...  ...        ...        ...             ...
# 100382      2058.70     12   29        363          2               0
# 100383      1846.90     12   30        364          3               0
# 100384      1657.50     12   31        365          4               0
# 100385       729.34     12   28        362          1               0
# 100386       623.80     12   28        362          1               0
#
#         is_month_end  is_wknd  daily_avg  montly_avg  rolling_mean10  \
# 0                  0     0.00      60.00         NaN             NaN
# 1                  0     0.00     154.60         NaN             NaN
# 2                  0     0.00     152.75         NaN             NaN
# 3                  0     1.00     202.67         NaN             NaN
# 4                  0     1.00     130.67         NaN             NaN
# ...              ...      ...        ...         ...             ...
# 100382             0     0.00      17.75         NaN           20.50
# 100383             0     0.00      15.60         NaN           20.90
# 100384             1     0.00      15.00         NaN           20.70
# 100385             0     0.00       5.00         NaN           18.50
# 100386             0     0.00       5.00         NaN           17.00
#
#         GL_NUMERO   pred
# 0              60  71.23
# 1              61 102.64
# 2              60  99.81
# 3             149 201.81
# 4              99 133.12
# ...           ...    ...
# 100382         19  17.97
# 100383         21  17.06
# 100384         15  16.11
# 100385          5   4.72
# 100386          5   4.72
#
# [100387 rows x 13 columns]

# %%
r = r2_score(Dec['pred'], Dec['GL_NUMERO'])

# %%
r
# Out:
# 0.8532631398326076

# %%
df_total
# Out:
#         GL_TOTALTTC  GL_NUMERO  month  day  dayofyear  dayofweek  \
# 0           3511.72        141      9    1        244          2
# 1           2230.77        110      9    2        245          3
# 2           2635.27        124      9    3        246          4
# 3           1776.33         85      9    4        247          5
# 4            703.39         39      9    6        249          0
# ...             ...        ...    ...  ...        ...        ...
# 283741      3136.10         28     11   26        330          4
# 283742      2232.60         17     11   27        331          5
# 283743      2495.80         19     11   29        333          0
# 283744       692.00          6     11   30        334          1
# 283745       620.00          2     11   18        322          3
#
#         is_month_start  is_month_end  is_wknd  daily_avg  monthly_avg  \
# 0                    1             0     0.00     141.00       141.00
# 1                    0             0     0.00      81.64        82.17
# 2                    0             0     0.00      88.64        82.17
# 3                    0             0     1.00     118.18        95.33
# 4                    0             0     0.00      53.11        82.17
# ...                ...           ...      ...        ...          ...
# 283741               0             0     0.00      14.00         9.95
# 283742               0             0     1.00      22.08        18.25
# 283743               0             0     0.00       8.17         9.95
# 283744               0             1     0.00       6.00         6.00
# 283745               0             0     0.00       2.00         2.00
#
#         rolling_mean10
# 0                  NaN
# 1                  NaN
# 2                  NaN
# 3                  NaN
# 4                  NaN
# ...                ...
# 283741           11.60
# 283742           12.70
# 283743           14.50
# 283744           14.40
# 283745             NaN
#
# [283746 rows x 12 columns]

# %%
df_total
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-485ddbec4446> in <module>
# ----> 1 df_total
#
# NameError: name 'df_total' is not defined

# %%
pip freeze > requirements.txt
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
Dec.to_csv('Decembre_tested.csv')

# %%
Dec.to_csv('Prediction_Decembre.csv')
